# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohammedaslaan/Machine-Learning-Projects/blob/main/Submarine_Rock_Vs_Mine_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Copy of sonar data.csv')

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.describe()
# Out:
#            0.0200      0.0371      0.0428      0.0207      0.0954      0.0986  \
# count  207.000000  207.000000  207.000000  207.000000  207.000000  207.000000
# mean     0.029208    0.038443    0.043837    0.054053    0.075105    0.104599
# std      0.023038    0.033040    0.038521    0.046583    0.055669    0.059247
# min      0.001500    0.000600    0.001500    0.005800    0.006700    0.010200
# 25%      0.013300    0.016400    0.018900    0.024450    0.037700    0.066950
# 50%      0.022800    0.030800    0.034200    0.044100    0.062000    0.092100
# 75%      0.035800    0.048100    0.058200    0.065700    0.101050    0.134150
# max      0.137100    0.233900    0.305900    0.426400    0.401000    0.382300
#
#            0.1539      0.1601      0.3109      0.2111  ...      0.0232  \
# count  207.000000  207.000000  207.000000  207.000000  ...  207.000000
# mean     0.121591    0.134677    0.177361    0.208245  ...    0.016034
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0.0200  207 non-null    float64
#  1   0.0371  207 non-null    float64
#  2   0.0428  207 non-null    float64
#  3   0.0207  207 non-null    float64
#  4   0.0954  207 non-null    float64
#  5   0.0986  207 non-null    float64
#  6   0.1539  207 non-null    float64
#  7   0.1601  207 non-null    float64
#  8   0.3109  207 non-null    float64
#  9   0.2111  207 non-null    float64
#  10  0.1609  207 non-null    float64
#  11  0.1582  207 non-null    float64
#  12  0.2238  207 non-null    float64
#  13  0.0645  207 non-null    float64
#  14  0.0660  207 non-null    float64
#  15  0.2273  207 non-null    float64
#  16  0.3100  207 non-null    float64
#  17  0.2999  207 non-null    float64
#  18  0.5078  207 non-null    float64
#  19  0.4797  207 non-null    float64
# ...

# %%
df.columns
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
df['R'].unique()
# Out:
# array(['R', 'M'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['R'] = le.fit_transform(df['R'])

# %%
df['R'].dtypes
# Out:
# dtype('int64')

# %%
df['R']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 202    0
# 203    0
# 204    0
# 205    0
# 206    0
# Name: R, Length: 207, dtype: int64

# %%
df.corr()
# Out:
#           0.0200    0.0371    0.0428    0.0207    0.0954    0.0986    0.1539  \
# 0.0200  1.000000  0.736104  0.571706  0.490853  0.345744  0.238824  0.262095
# 0.0371  0.736104  1.000000  0.779915  0.607297  0.419877  0.332319  0.279328
# 0.0428  0.571706  0.779915  1.000000  0.782662  0.546365  0.346271  0.190628
# 0.0207  0.490853  0.607297  0.782662  1.000000  0.729338  0.352901  0.248713
# 0.0954  0.345744  0.419877  0.546365  0.729338  1.000000  0.597438  0.334831
# ...          ...       ...       ...       ...       ...       ...       ...
# 0.0180  0.319663  0.282822  0.383945  0.349411  0.218004  0.163433  0.183382
# 0.0084  0.368413  0.353061  0.334122  0.345537  0.238749  0.204027  0.242632
# 0.0090  0.357611  0.352260  0.425100  0.421410  0.290793  0.220678  0.183279
# 0.0032  0.346302  0.359010  0.374256  0.399262  0.255220  0.178027  0.224536
# R      -0.270482 -0.231670 -0.192589 -0.247935 -0.224809 -0.132172 -0.117848
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('R',axis=1 )
y = df['R']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=1,test_size=0.1)

# %%
x_train.shape
# Out:
# (186, 60)

# %%
x_test.shape
# Out:
# (21, 60)

# %%
y_train.shape
# Out:
# (186,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression()

# %%
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = classifier.predict(x_test)

# %%
result = pd.DataFrame({
    'actual' : y_test,
    'predicted': y_pred
})

# %%
result
# Out:
#      actual  predicted
# 186       0          0
# 155       0          0
# 165       0          0
# 200       0          0
# 58        1          1
# 34        1          0
# 151       0          0
# 18        1          0
# 202       0          0
# 62        1          1
# 4         1          1
# 47        1          1
# 110       0          0
# 205       0          0
# 105       0          1
# 172       0          0
# 31        1          1
# 198       0          0
# 33        1          1
# 40        1          1
# 175       0          0

# %%
count = len(result[result['actual'] == result['predicted']])

# %%
count
# Out:
# 18

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8571428571428571

# %%
import numpy as np

s = "0.0164 0.0173 0.0347 0.007 0.0187 0.0671 0.1056 0.0697 0.0962 0.0251 0.0801 0.1056 0.1266 0.089 0.0198 0.1133 0.2826 0.3234 0.3238 0.4333 0.6068 0.7652 0.9203 0.9719 0.9207 0.7545 0.8289 0.8907 0.7309 0.6896 0.5829 0.4935 0.3101 0.0306 0.0244 0.1108 0.1594 0.1371 0.0696 0.0452 0.062 0.1421 0.1597 0.1384 0.0372 0.0688 0.0867 0.0513 0.0092 0.0198 0.0118 0.009 0.0223 0.0179 0.0084 0.0068 0.0032 0.0035 0.0056 0.004 R"

# Convert string to NumPy array
arr = np.fromstring(s, sep=' ')

pd.DataFrame(arr)
# Out:
# <ipython-input-47-bb2ddddcc770>:6: DeprecationWarning: string or file could not be read to its end due to unmatched data; this will raise a ValueError in the future.
#   arr = np.fromstring(s, sep=' ')
#          0
# 0   0.0164
# 1   0.0173
# 2   0.0347
# 3   0.0070
# 4   0.0187
# 5   0.0671
# 6   0.1056
# 7   0.0697
# 8   0.0962
# 9   0.0251
# 10  0.0801
# 11  0.1056
# 12  0.1266
# 13  0.0890
# 14  0.0198
# 15  0.1133
# 16  0.2826
# 17  0.3234
# 18  0.3238
# 19  0.4333
# 20  0.6068
# 21  0.7652
# 22  0.9203
# 23  0.9719
# 24  0.9207
# 25  0.7545
# 26  0.8289
# 27  0.8907
# 28  0.7309
# 29  0.6896
# 30  0.5829
# 31  0.4935
# 32  0.3101
# 33  0.0306
# 34  0.0244
# 35  0.1108
# 36  0.1594
# 37  0.1371
# 38  0.0696
# 39  0.0452
# 40  0.0620
# 41  0.1421
# 42  0.1597
# 43  0.1384
# 44  0.0372
# 45  0.0688
# 46  0.0867
# 47  0.0513
# 48  0.0092
# 49  0.0198
# 50  0.0118
# 51  0.0090
# 52  0.0223
# 53  0.0179
# 54  0.0084
# 55  0.0068
# 56  0.0032
# 57  0.0035
# 58  0.0056
# 59  0.0040

# %%
import pandas as pd

data = {
    'Value': [
        0.0164, 0.0173, 0.0347, 0.0070, 0.0187, 0.0671, 0.1056, 0.0697, 0.0962, 0.0251,
        0.0801, 0.1056, 0.1266, 0.0890, 0.0198, 0.1133, 0.2826, 0.3234, 0.3238, 0.4333,
        0.6068, 0.7652, 0.9203, 0.9719, 0.9207, 0.7545, 0.8289, 0.8907, 0.7309, 0.6896,
        0.5829, 0.4935, 0.3101, 0.0306, 0.0244, 0.1108, 0.1594, 0.1371, 0.0696, 0.0452,
        0.0620, 0.1421, 0.1597, 0.1384, 0.0372, 0.0688, 0.0867, 0.0513, 0.0092, 0.0198,
        0.0118, 0.0090, 0.0223, 0.0179, 0.0084, 0.0068, 0.0032, 0.0035, 0.0056, 0.0040
    ]
}

df = pd.DataFrame(data)

df_transposed = df.transpose()

df_transposed
# Out:
#            0       1       2      3       4       5       6       7       8   \
# Value  0.0164  0.0173  0.0347  0.007  0.0187  0.0671  0.1056  0.0697  0.0962
#
#            9   ...      50     51      52      53      54      55      56  \
# Value  0.0251  ...  0.0118  0.009  0.0223  0.0179  0.0084  0.0068  0.0032
#
#            57      58     59
# Value  0.0035  0.0056  0.004
#
# [1 rows x 60 columns]

# %%
classifier.predict(df_transposed)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
